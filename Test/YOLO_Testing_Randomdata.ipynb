# %%
from ultralytics import YOLO

# Path to model and test images
model_path = r"C:\Users\Pongo\OneDrive\Documents\~Cornel\~Ideas n Innovation\Project\25-4-22 -- Parkinson Unika\best.pt"
test_images_path = r"C:\Users\Pongo\OneDrive\Documents\~Cornel\~Ideas n Innovation\Project\25-4-22 -- Parkinson Unika\Dataset\test\test"

# Load the model
model = YOLO(model_path)

# Run prediction
results = model.predict(
    source=test_images_path,
    imgsz=512,
    conf=0.25,   # Confidence threshold
    save=True    # Saves images with predictions to runs/detect/predict
)

print("✅ Prediction completed. Check the results in 'runs/detect/predict'")
# Out:
# image 1/204 C:\Users\Pongo\OneDrive\Documents\~Cornel\~Ideas n Innovation\Project\25-4-22 -- Parkinson Unika\Dataset\test\test\V01HE01.png: 512x512 1 healthy spiral, 15.6ms
# image 2/204 C:\Users\Pongo\OneDrive\Documents\~Cornel\~Ideas n Innovation\Project\25-4-22 -- Parkinson Unika\Dataset\test\test\V01HE02.png: 512x512 1 healthy spiral, 21.7ms
# image 3/204 C:\Users\Pongo\OneDrive\Documents\~Cornel\~Ideas n Innovation\Project\25-4-22 -- Parkinson Unika\Dataset\test\test\V01HE03.png: 512x512 1 healthy spiral, 24.8ms
# image 4/204 C:\Users\Pongo\OneDrive\Documents\~Cornel\~Ideas n Innovation\Project\25-4-22 -- Parkinson Unika\Dataset\test\test\V01HO01.png: 256x512 1 parkinson wave, 150.4ms
# image 5/204 C:\Users\Pongo\OneDrive\Documents\~Cornel\~Ideas n Innovation\Project\25-4-22 -- Parkinson Unika\Dataset\test\test\V01HO02.png: 288x512 1 healthy wave, 105.8ms
# ...
